# %% [markdown]
# # Session 1 — Model Comparison with MLflow
#
# **Goal:** Train three model types (Logistic Regression, Random Forest, Gradient Boosted Trees)
# and use the [MLflow UI](https://docs.databricks.com/aws/en/mlflow/runs) to compare their performance.
#
# **Business question:** For a churn model, which metric should we optimize?
# - **Accuracy**: Overall correct predictions (misleading with class imbalance)
# - **Precision**: Of predicted churners, how many actually churned? (false alarm rate)
# - **Recall**: Of actual churners, how many did we catch? (missed customers)
# - **F1**: Harmonic mean of precision and recall (balanced)
#
# For churn, **recall** is often prioritized — a missed churner costs more than an unnecessary retention offer.

# %%
# %run ../utils/config

# %%
# %pip install ../bundle/wheels/ databricks-feature-engineering --quiet

# %%
import yaml, mlflow


config_path = "../common/config.yml"
with open(config_path) as f:
    config = yaml.safe_load(f)

# Construct the experiment name
current_user = spark.sql("SELECT current_user()").first()[0]
experiment_name = f"/Users/{current_user}/churn_{safe_username}"
print(f"Experiment: {experiment_name}")

# %% [markdown]
# ## Set Up the Feature Store
#
# Going forward, we will publish our features to the **[Unity Catalog Feature Engineering](https://docs.databricks.com/aws/en/machine-learning/feature-store/uc/feature-tables-uc)** table.
#
# **Why?** Two layers work together to prevent [train/serving skew](https://docs.databricks.com/aws/en/machine-learning/feature-store/train-models-with-feature-store):
#
# 1. **[Feature Store](https://docs.databricks.com/aws/en/machine-learning/feature-store/) (this step)** — VALUE consistency.
#    Feature values are stored once in a [Delta table](https://docs.databricks.com/aws/en/delta/) and retrieved identically at training and serving time via [feature lookups](https://docs.databricks.com/aws/en/machine-learning/feature-store/train-models-with-feature-store#create-a-trainingset). No risk of a different code path computing `TotalCharges` differently in the scoring pipeline.
# 1. **`features.py` sklearn pipeline** — TRANSFORMATION consistency.
#    Imputation, scaling, and one-hot encoding are defined once and embedded in the MLflow artifact. The same transformations run everywhere.
#
#
# The [Feature Store table](https://docs.databricks.com/aws/en/machine-learning/feature-store/feature-tables) (`churn_features`) — written via [`fe.write_table()`](https://docs.databricks.com/aws/en/machine-learning/feature-store/python-api) with `mode="merge"` for upserts by [primary key](https://docs.databricks.com/aws/en/machine-learning/feature-store/feature-tables#create-a-feature-table-in-unity-catalog) — will be the source of truth for all future training runs, including the automated retrain job in Session 2.
#
# <img src=../utils/resources/feature_store_consistency.png>

# %%
from databricks.feature_engineering import FeatureEngineeringClient, FeatureLookup


fe = FeatureEngineeringClient()

# Name of the feature store to be created
feature_table = f"{catalog}.{schema}.churn_features"

# Feature columns (defined in the config file) + lookup key
feature_cols = (
    config["feature_columns"]["numeric"]
    + config["feature_columns"]["categorical"]
    + ["customerID"]
)

# Read from the shared source table
raw_df = spark.table(f"{catalog}.`00_shared`.telco_churn")
features_df = raw_df.select(*feature_cols).dropDuplicates(["customerID"])

# Create the table on first run; merge (upsert) on subsequent runs
try:
    fe.create_table(
        name=feature_table,
        primary_keys=["customerID"],
        df=features_df,
        description="Telco churn features — source of truth for training and serving",
    )
    print(f"✓ Created feature table: {feature_table}")
except Exception as e:
    if "already exists" in str(e).lower():
        fe.write_table(name=feature_table, df=features_df, mode="merge")
        print(f"✓ Updated feature table: {feature_table}")
    else:
        raise

print(f"  Rows: {features_df.count():,}")

# Build the training set — Feature Store joins labels with feature lookups by customerID
label_df = raw_df.select("customerID", config.get("target_column", "Churn"))

training_set = fe.create_training_set(
    df=label_df,
    feature_lookups=[
        FeatureLookup(
            table_name=feature_table,
            lookup_key="customerID",
        )
    ],
    label=config.get("target_column", "Churn"),
    exclude_columns=["customerID"],
)
print(f"✓ Training set created — {label_df.count():,} labels linked to feature table")

# %% [markdown]
# ## Train Three Models
#
# The following cell will create three MLflow runs in your experiment — one per model type defined in `config.yml`:
# - Logistic Regression,
# - Random Forest,
# - Gradient Boost with Trees
#
# Expect this to take 1-2 minutes.
#
# <img src=../utils/resources/sklearn_pipeline.png>

# %%
import warnings
from churn_model.train import run_all_models

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=UserWarning, module="mlflow")

    # Function in the churn_model/train.py module that trains all model types listed in the config file
    results = run_all_models(
        catalog=catalog,
        schema=schema,
        config=config,
        experiment_name=experiment_name,
        fe=fe,
        training_set=training_set,
    )

print("\nAll models trained!")

# %% [markdown]
# ## View Results in MLflow UI
#
# 1. Open **[Experiments](https://docs.databricks.com/aws/en/mlflow/experiments)** from the left sidebar in a new browser tab
# 2. Find your <span style="color:cc0000;background-color:#e0e0e0;font-family:courier">churn_{safe_username}</span> experiment.
# 3. Select all three runs → click **Compare**
# 4. Look at the **[Parallel Coordinates](https://docs.databricks.com/aws/en/mlflow/runs#parallel-coordinates-plot)** plot.  Add the `model_type` parameter and `test_recall` and `test_f1` metrics
#
# **Questions to discuss:**
# - Which model has the highest F1?
# - Which has the highest Recall?
# - Is there a precision-recall trade-off visible?
# - How much does training time differ between models?

# %%
# Also view results programmatically
print(f"{'Model':<30} {'F1':>8} {'ROC-AUC':>10} {'Recall':>8} {'Precision':>10}")
print("-" * 68)
for r in results:
    m = r.metrics
    print(f"{r.model_type:<30} {m['test_f1']:>8.4f} {m['test_roc_auc']:>10.4f} "
          f"{m['test_recall']:>8.4f} {m['test_precision']:>10.4f}")

# %% [markdown]
# ## Find the Best Run
#
# Let's programmatically identify the best model by F1 score.

# %%
from churn_model.evaluate import get_best_run

best_run_id, best_model_type, best_metrics = get_best_run(
    experiment_name=experiment_name,
    metric="test_f1",
)

print(f"Best model : {best_model_type}")
print(f"Run ID     : {best_run_id}")
print(f"F1         : {best_metrics['test_f1']:.4f}")
print(f"ROC-AUC    : {best_metrics['test_roc_auc']:.4f}")
print(f"Recall     : {best_metrics['test_recall']:.4f}")

# Save for next notebook
dbutils.jobs.taskValues.set("best_run_id", best_run_id)
dbutils.jobs.taskValues.set("best_model_type", best_model_type)

# %% [markdown]
# <div style="
#   border-left: 4px solid #f44336;
#   background: #ffebee;
#   padding: 14px 18px;
#   border-radius: 4px;
#   margin: 16px 0;
# ">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Copy the Run ID</strong>
#   <div style="color:#333;">
#
# **NOTE:**  After the cell finishes running, Copy the **Run ID** from the output above.  You will need this run ID in the next notebook to register the model.
#   </div>
# </div>

# %% [markdown]
# ## Discussion
#
# - Logistic Regression typically wins on this dataset by a small margin
# - The difference between models is often small — MLOps process matters more than model selection
# - MLflow makes it easy to re-run this comparison after retraining on new data

# %% [markdown]
# ➡️ Next: [05_register_and_serve.ipynb]($./05_register_and_serve) — register the best model and deploy it

# %% [markdown]
# ## 📚 Going deeper — questions a curious MLE / DS might ask
#
# **Feature Store — beyond the basics**
# - *"How do I get point-in-time correct feature values for time-series labels (e.g. churn within 90 days from a snapshot)?"* → [Time-series feature tables and as-of joins](https://docs.databricks.com/aws/en/machine-learning/feature-store/time-series-feature-tables)
# - *"My features are computed at request time (e.g. user's current cart total) — can I avoid materialising them?"* → [On-demand features with Python UDFs](https://docs.databricks.com/aws/en/machine-learning/feature-store/on-demand-features)
# - *"My feature pipeline is streaming — can the offline FS table stay fresh without me re-running it?"* → [Feature Store with Lakeflow Spark Declarative Pipelines](https://docs.databricks.com/aws/en/machine-learning/feature-store/feature-tables#stream-features-to-a-feature-table)
# - *"What happens if I add or drop a feature column — do my old training sets still work?"* → [Modify feature tables and schema evolution](https://docs.databricks.com/aws/en/machine-learning/feature-store/modify-feature-table)
# - *"How do online tables stay in sync with the offline FS Delta table?"* → [Online tables sync](https://docs.databricks.com/aws/en/machine-learning/feature-store/online-tables) — Continuous, Triggered, or Snapshot pipelines
#
# **MLflow comparison — niche**
# - *"How do I find the best run programmatically with custom criteria (e.g. F1 ≥ 0.85 AND latency < 50 ms)?"* → [Search runs with filter strings](https://docs.databricks.com/aws/en/mlflow/search-runs)
# - *"Can I log datasets (not just metrics) with MLflow for full reproducibility?"* → [MLflow dataset tracking](https://docs.databricks.com/aws/en/mlflow/tracking#track-datasets-used-during-training)
# - *"How do the three confusion-matrix metrics (precision/recall/F1) trade off with class imbalance?"* → [scikit-learn metrics](https://scikit-learn.org/stable/modules/model_evaluation.html#classification-metrics)
